# %% [markdown]
# ## 파이썬 기초

# %%
import tensorflow as tf

# %%
print(tf.version)
# Out:
# <module 'tensorflow._api.v2.version' from '/usr/local/lib/python3.6/dist-packages/tensorflow/_api/v2/version/__init__.py'>

# %%
# 이 코드는 우리가 처음으로 만들어 본 코드입니다. 이게 세상의 변화를 가져오는 시작입니다.

print('Hello World form the Hell')
# Out:
# Hello World form the Hell

# %%
# 변수 만들기

# Integer Variable
numberOfRocks = 5

# Float Variable
tempInSpace = -170.87

# String Variable
roverName = "Artemis Rover"

# Boolean Variable
rocketOn = False

print(numberOfRocks)
# Out:
# 5

# %%
print(roverName)
# Out:
# Artemis Rover

# %%
# Create integer variable named basaltRockCount with value 0
basaltRockCount = 342342342
print("처음 값은 ", basaltRockCount)

basaltRockCount = 3
print("두번째 값은 ", basaltRockCount)
basaltRockCount = basaltRockCount + 1
print("세번째 값은 ", basaltRockCount)

basaltRockCount += 3 #Add 3
print("+=3의 결과는 ", basaltRockCount)

basaltRockCount -= 2 #Remove 2
print("-=2의 결과는 ", basaltRockCount)
# Out:
# 처음 값은  342342342
# 두번째 값은  3
# 세번째 값은  4
# +=3의 결과는  7
# -=2의 결과는  5

# %%
# 문자열을 다루어보도록 하겠습니다.
astronaut = "Remy Morris"
print(" 원래 문자열은 ", astronaut)

upperCase = astronaut.upper()  # upper는 모두 대문자로 출력하도록 하는 method입니다.
print(" upper method를 적용한 문자열은 ", upperCase)

lowerCase = astronaut.lower()  # lower는 모두 소문자로 출력하도록 하는 method입니다.
print(" lower method를 적용한 문자열은 ", lowerCase)
# Out:
#  원래 문자열은  Remy Morris
#  upper method를 적용한 문자열은  REMY MORRIS
#  lower method를 적용한 문자열은  remy morris

# %%
# Create a list of common moon rocks
rockTypes = ["basalt", "highland", "breccia"]

# A list with rock names and the number of that rock found
rockTypeAndCount = ["basalt", 1, "highland", 2.5, "breccia", 5]

print("데이터 목록(리스트)은 ", rockTypes)
print("목록에는 서로 다른 형식을 조합할 수 있어", rockTypeAndCount,"와 같이 사용 가능")
# Out:
# 데이터 목록(리스트)은  ['basalt', 'highland', 'breccia']
# 목록에는 서로 다른 형식을 조합할 수 있어 ['basalt', 1, 'highland', 2.5, 'breccia', 5] 와 같이 사용 가능

# %%
# 데이터 목록에 데이터 추가하기 - append
rockTypes.append("soil")
print("append로 추가한 후 데이터 목록은 ", rockTypes)

# 데이터 목록에 데이터 삭제하기- pop은 목록의 끝에 있는 항목을 삭제함.
rockTypes.pop()
print("pop으로 삭제한 후 데이터 목록은 ", rockTypes)
# Out:
# append로 추가한 후 데이터 목록은  ['basalt', 'highland', 'breccia', 'soil']
# pop으로 삭제한 후 데이터 목록은  ['basalt', 'highland', 'breccia']

# %%
# 목록에 있는 데이터 접근하기
print("데이터 목록의 내용은 ", rockTypes)
print("데이터 목록에서 첫 번째 위치 데이터 가져오면", rockTypes[0])
print("데이터 목록에서 두 번째와 세 번째 위치 데이터 가져오면", rockTypes[1:3])
# Out:
# 데이터 목록의 내용은  ['basalt', 'highland', 'breccia']
# 데이터 목록에서 첫 번째 위치 데이터 가져오면 basalt
# 데이터 목록에서 두 번째와 세 번째 위치 데이터 가져오면 ['highland', 'breccia']

# %% [markdown]
# ## 파이썬 프로그램 제어문

# %%
# 비교하기 
temp = 50
print(temp >= 32)

# 비교하기 - 동치 검사
rock = "basalt"               # 프로그래밍 언어에서 '='는 대입 연산자로 '같음'을 의미하지 않음
print("highland" == rock)     # 프로그래밍 언어에서 같음은 '==' 논리 연산자를 이용함.
print("basalt" == rock)       # 비교한 후 결과를 True / False로 반환함

print("highland" in rock)      # "highland"라는 단어가 변수 rock에 있는지 검사하고 T/F를 반환 
print(rock in rockTypes)        # 이 형식은 원래 데이터 목록(리스트)안에 항목이 있는지 검사하는 형태로 자주 사용
# Out:
# True
# False
# True
# False
# True

# %%
if(조건):
  수행

if(온도가 어느 점보다 떨어지면):
  로켓을 발사한다.

# %%
basalt = 0
if(basalt == 0):
    print("We have found no basalt rocks")
print("Done checking basalt rocks")
# Out:
# We have found no basalt rocks
# Done checking basalt rocks

# %%
basalt = 0
if(basalt == 0):
    print("We have found no basalt rocks")
else:
    print("We found some basalt rocks")
print("Done checking basalt rocks")
# Out:
# We have found no basalt rocks
# Done checking basalt rocks

# %%
basalt = 1
if(basalt == 0):
    print("We found no basalt rocks")
elif(basalt == 1):
    print("We found exactly 1 basalt rock")
else:
    print("We found more than 1 basalt rock")
print("Done checking basalt rocks")
# Out:
# We found exactly 1 basalt rock
# Done checking basalt rocks

# %%
# while 반복문 예시

countdown = 5

while countdown >= 0:
    print(countdown)
    countdown = countdown - 1  
print("Lift Off")
# Out:
# 5
# 4
# 3
# 2
# 1
# 0
# Lift Off

# %%
# for 반복문

planets = "Mars","Saturn", "Jupiter"

for planet in planets:
    print(planet)
# Out:
# Mars
# Saturn
# Jupiter

# %%
for i in range(1,9):
  for j in range(1,9):
    print(i,"x", j, "=", i*j)
# Out:
# 1 x 1 = 1
# 1 x 2 = 2
# 1 x 3 = 3
# 1 x 4 = 4
# 1 x 5 = 5
# 1 x 6 = 6
# 1 x 7 = 7
# 1 x 8 = 8
# 2 x 1 = 2
# 2 x 2 = 4
# 2 x 3 = 6
# 2 x 4 = 8
# 2 x 5 = 10
# 2 x 6 = 12
# 2 x 7 = 14
# 2 x 8 = 16
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 4 x 1 = 4
# 4 x 2 = 8
# 4 x 3 = 12
# 4 x 4 = 16
# 4 x 5 = 20
# 4 x 6 = 24
# 4 x 7 = 28
# 4 x 8 = 32
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 6 x 1 = 6
# 6 x 2 = 12
# 6 x 3 = 18
# 6 x 4 = 24
# 6 x 5 = 30
# 6 x 6 = 36
# 6 x 7 = 42
# 6 x 8 = 48
# 7 x 1 = 7
# 7 x 2 = 14
# 7 x 3 = 21
# 7 x 4 = 28
# 7 x 5 = 35
# 7 x 6 = 42
# 7 x 7 = 49
# 7 x 8 = 56
# 8 x 1 = 8
# 8 x 2 = 16
# 8 x 3 = 24
# 8 x 4 = 32
# 8 x 5 = 40
# 8 x 6 = 48
# 8 x 7 = 56
# 8 x 8 = 64

# %% [markdown]
# ## 파이썬 함수 만들기

# %% [markdown]
# 함수의 형태
#
#
# ```
# def NameOfFunction():
#   return
# ```

# %%
# 이런 함수를 만들지 않겠지만 카운트다운 함수 선언하기
def OutputRocketText():
  print(5)
  print(4)
  print(3)
  print(2)
  print(1)
  print("Rocket will be launching soon!")
  return

OutputRocketText()   # 함수 호출하기
# Out:
# 5
# 4
# 3
# 2
# 1
# Rocket will be launching soon!

# %%
rocketText = "We will launch in"
def OutputRocketText():
    rocketText = rocketText + " two days"

    return

OutputRocketText()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-36-f36e0da311a3> in <module>()
#       5     return
#       6
# ----> 7 OutputRocketText()
#
# <ipython-input-36-f36e0da311a3> in OutputRocketText()
#       1 rocketText = "We will launch in"
#       2 def OutputRocketText():
# ----> 3     rocketText = rocketText + " two days"
#       4
#       5     return
#
# UnboundLocalError: local variable 'rocketText' referenced before assignment

# %%
rocketText = "We will launch in"

def OutputRocketText():
    global rocketText
    rocketText = rocketText + " two days"

    return

OutputRocketText()
print(rocketText)
# Out:
# We will launch in two days

# %%
def OutputRocketText():
    rocketNumber = 1
    print("Rocket will launch soon!")

    return

OutputRocketText()
print(rocketNumber)
# Out:
# Rocket will launch soon!
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-f24464d9d2ed> in <module>()
#       6
#       7 OutputRocketText()
# ----> 8 print(rocketNumber)
#
# NameError: name 'rocketNumber' is not defined

# %%
def OutputRocketText(textInput):

    textInput = textInput + " two days"

    return textInput

rocketText = "We will launch in"
newRocketText = OutputRocketText(rocketText)
print(newRocketText)
# Out:
# We will launch in two days

# %% [markdown]
# ## 데이터 가져오기

# %%
strPath = "rocks.txt"                       # 파일 경로를 저장할 변수 생성

fileObject = open(strPath)                 # open() method를 이용하여 파일 열기
textList = fileObject.readlines()          # 파일을 읽어 txtList에 저장하기
fileObject.close()                         # 파일 닫기

for line in textList:                      # txtList에 있는 내용을 출력하기
    print(line)

# %%
firstLine = textList[0]                    # txtList에 있는 첫 번째 줄 가져오기
print(firstLine)

secondLine = textList[1:]                   # txtList에 있는 두 번째 줄부터 가져오기
print(secondLine)
# Out:
# Reading Rocks
#
# ['basalt\n', 'breccia\n', 'highland\n', 'regolith\n', 'highland\n', 'breccia\n', 'highland\n', 'regolith\n', 'regolith\n', 'basalt\n', 'highland\n', 'basalt\n', 'breccia\n', 'breccia\n', 'regolith\n', 'breccia\n', 'highland\n', 'highland\n', 'breccia\n', 'basalt']

# %% [markdown]
# ### 데이터를 편하게 만들어보기

# %% [markdown]
# % wget 이하 주소해서 파일을 다운로드
#
# !wget https://nasadata.blob.core.windows.net/nasarocks/Data.zip
#
# % mkdir 이하 이름으로 폴더 생성 (ex. rData 폴더 생성)
# !mkdir rData
#
# % Data.zip를 rData 폴더로 이동
#
# !mv Data.zip ./rData/
#
# % rData 폴더에 있는 Data.zip 압축 해제
# !cd rData && unzip Data.zip

# %%
# wget 이하 주소해서 파일을 다운로드 

# !wget https://nasadata.blob.core.windows.net/nasarocks/Data.zip

# mkdir 이하 이름으로 폴더 생성 (ex. rData 폴더 생성)
# !mkdir rData

# Data.zip를 rData 폴더로 이동 

# !mv Data.zip ./rData/ 

# rData 폴더에 있는 Data.zip 압축 해제 
# !cd rData && unzip Data.zip

# %% [markdown]
# ## 구글 코랩 단축키

# %% [markdown]
# * 코드가 오래 실행되어 멈추고 싶은경우 : Ctrl+ M + I
# * 엔터키 : 편집모드(Vi 편집기와 유사)
# * ESC : 선택모드(Vi 편집기와 유사)
# * 선택모드에서 화살표 방향키 : 셀 포커스를 위 아래로 움직일 수 있음
# * 마크다운으로 전환 : Ctrl + M M
# * 코드로 전환 : Ctrl + M Y
# * 선택된 셀을 실행 : Ctrl + Enter
# * 선택된 셀을 실행 후 다음 셀로 포커스 이동 : Shift + Enter
# * 실행 후 다음줄로 이동 : Alt + Enter
# * 코드셀에 줄번호 부여 : Ctrl + M L
# * 바로 윗줄에 셀 생성 : Ctrl + M A
# * 바로 아랫줄에 셀 생성 : Ctrl + M B
# * 셀 삭제 : Ctrl + M D
# * 저장 : Ctrl + S

# %% [markdown]
# **표 그리기**
#
# |                  | 수학                        | 평가              |
# |:--- | ---: | :---: |
# | 철수             | 90            | 참잘했어요. |
# | 영희           | 50            | 분발하세요. |

# %% [markdown]
# ## 파이썬 적용해보기 - 우주 암석 분류하기
#
# **자료 출처**
# https://docs.microsoft.com/ko-kr/learn/modules/analyze-rock-images-ai-nasa/1-introduction
#
# [ 배울 내용 ]
# >* AI 라이브러리 가져오기
# * 데이터를 가져오는 방법 알아보기
# * 데이터를 정리하 고 분리하는 방법 알아보기
# * 가져온 데이터 표시

# %% [markdown]
# ### 1. 필요한 라이브러리 불러오기

# %%
# 데이터를 시각화하기 위한 그래프 라이브러리
import matplotlib.pyplot as plt

# %%
# 숫자(행렬)을 처리하기 위한 과학 기술 라이브러리
import numpy as np

# %%
# 딥러닝 및 인공 지능 모델을 학습시키고 처리하기 위한 PyTorch 모델 라이브러리
# Tensorflow, keras, scikit-learn 등 다양한 라이브러리가 있으며 오늘은 pytorch를 이용함
import torch
from torch import nn, optim
from torch.autograd import Variable
import torch.nn.functional as F

# %%
# 이미지 처리를 위한 라이브러리로 Pytorch 안에 포함되어 있음.
import torchvision
from torchvision import datasets, transforms, models

# %%
# 이미지 시각화를 위한 파이썬에서 제공하는 이미지 처리 라이브러리 불러오기
from PIL import Image

# %%
# 그래프를 주피터 노트북에 직접 표시하는 라이브러리 추가
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# ### 2. 데이터 전처리하기

# %% [markdown]
# **데이터 정리하기**
#
# * 데이터 특히 이미지 크기가 동일한지 검사하기
# * 특정 데이터에 누락 데이터가 있는지 검사하기
#
# **데이터 분리하기**
# * 학습 데이터와 테스트 데이터 그룹으로 나누기
# * 데이터의 80% 정도를 학습 데이터로, 20% 정도를 테스트 데이터로 분류

# %%
# 이미지 파일이 있는 위치를 data_dir 변수에 저장함.
data_dir = '/content/rData/Data/'

# %%
# Function to read the data; crop and resize the images; and then split it into test and train chunks.
def load_split_train_test(datadir, valid_size = .2):
    # This line of code transforms the images.
    train_transforms = transforms.Compose([
                                       transforms.RandomResizedCrop(224),
                                       transforms.Resize(224),
                                       transforms.ToTensor(),
                                       ])

    test_transforms = transforms.Compose([transforms.RandomResizedCrop(224),
                                          transforms.Resize(224),
                                          transforms.ToTensor(),
                                      ])

    train_data = datasets.ImageFolder(datadir, transform=train_transforms)
    test_data = datasets.ImageFolder(datadir, transform=test_transforms)

    num_train = len(train_data)
    indices = list(range(num_train))
    split = int(np.floor(valid_size * num_train))
    np.random.shuffle(indices)
    from torch.utils.data.sampler import SubsetRandomSampler
    train_idx, test_idx = indices[split:], indices[:split]
    train_sampler = SubsetRandomSampler(train_idx)
    test_sampler = SubsetRandomSampler(test_idx)
    trainloader = torch.utils.data.DataLoader(train_data, sampler=train_sampler, batch_size=16)
    testloader = torch.utils.data.DataLoader(test_data, sampler=test_sampler, batch_size=16)
    return trainloader, testloader

# %%
# We're using 20% of data for testing.
trainloader, testloader = load_split_train_test(data_dir, .2)
print(trainloader.dataset.classes)
# Out:
# ['Basalt', 'Highland']

# %%
# Transform the new image into numbers and resize it.
test_transforms = transforms.Compose([transforms.RandomResizedCrop(224),
                                      transforms.Resize(224),
                                      transforms.ToTensor(),
                                    ])

# A function to randomly select a set of images.
def get_random_images(num):
    data = datasets.ImageFolder(data_dir, transform=test_transforms)
    classes = data.classes
    indices = list(range(len(data)))
    np.random.shuffle(indices)
    idx = indices[:num]
    from torch.utils.data.sampler import SubsetRandomSampler
    sampler = SubsetRandomSampler(idx)
    loader = torch.utils.data.DataLoader(data, sampler=sampler, batch_size=num)
    dataiter = iter(loader)
    images, labels = dataiter.next()
    return images, labels

# %%
# How many images do you want to see? It's set to 5, but you can change the number.
images, labels = get_random_images(5)
to_pil = transforms.ToPILImage()
fig=plt.figure(figsize=(20,20))
classes=trainloader.dataset.classes
for ii in range(len(images)):
    image = to_pil(images[ii])
    sub = fig.add_subplot(1, len(images), ii+1)
    plt.axis('off')
    plt.imshow(image)
plt.show()

# %% [markdown]
# ## 인공지능을 이용하여 무작위 이미지를 분류하기

# %% [markdown]
# **이번 섹션에서 학습할 내용**
#
# * 인공 지능 모델 학습
# * 우주 암석의 무작위 사진을 분류하는 데 사용하여 모델을 테스트

# %%
# Determine whether you're using a CPU or a GPU to build the deep learning network.
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = models.resnet50(pretrained=True)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.cache/torch/hub/checkpoints/resnet50-19c8e357.pth
# ...

# %%
# Builds all the neurons.
for param in model.parameters():
    param.requires_grad = False

# The parameters of our deep learning model.
model.fc = nn.Sequential(nn.Linear(2048, 512),
                                 nn.ReLU(),
                                 nn.Dropout(0.2),
                                 nn.Linear(512, 2),
                                 nn.LogSoftmax(dim=1))
criterion = nn.NLLLoss()
optimizer = optim.Adam(model.fc.parameters(), lr=0.003)
model.to(device)
print('done')
# Out:
# done

# %%
epochs = 5
steps = 0
running_loss = 0
print_every = 5
train_losses, test_losses = [], []

for epoch in range(epochs):
    for inputs, labels in trainloader:

        steps += 1
        print('Training step ', steps)
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        logps = model.forward(inputs)
        loss = criterion(logps, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
        if steps % print_every == 0:
            test_loss = 0
            accuracy = 0
            model.eval()
            with torch.no_grad():
                for inputs, labels in testloader:
                    inputs, labels = inputs.to(device), labels.to(device)
                    logps = model.forward(inputs)
                    batch_loss = criterion(logps, labels)
                    test_loss += batch_loss.item()
                    
                    ps = torch.exp(logps)
                    top_p, top_class = ps.topk(1, dim=1)
                    equals = top_class == labels.view(*top_class.shape)
                    accuracy += torch.mean(equals.type(torch.FloatTensor)).item()

            train_losses.append(running_loss/len(trainloader))
            test_losses.append(test_loss/len(testloader))                    
            print(f"Epoch {epoch+1}/{epochs}.. "
                  f"Train loss: {running_loss/print_every:.3f}.. "
                  f"Test loss: {test_loss/len(testloader):.3f}.. "
                  f"Test accuracy: {accuracy/len(testloader):.3f}")
            running_loss = 0
            model.train()
# Out:
# Training step  1
# Training step  2
# Training step  3
# Training step  4
# Training step  5
# Epoch 1/5.. Train loss: 2.984.. Test loss: 0.847.. Test accuracy: 0.419
# Training step  6
# Training step  7
# Training step  8
# Training step  9
# Training step  10
# Epoch 2/5.. Train loss: 0.598.. Test loss: 1.093.. Test accuracy: 0.415
# Training step  11
# Training step  12
# Training step  13
# Training step  14
# Training step  15
# Epoch 2/5.. Train loss: 0.667.. Test loss: 0.459.. Test accuracy: 0.806
# Training step  16
# Training step  17
# Training step  18
# Training step  19
# Training step  20
# Epoch 3/5.. Train loss: 0.396.. Test loss: 0.508.. Test accuracy: 0.777
# Training step  21
# Training step  22
# Training step  23
# Training step  24
# Training step  25
# Epoch 4/5.. Train loss: 0.333.. Test loss: 0.538.. Test accuracy: 0.713
# Training step  26
# Training step  27
# Training step  28
# Training step  29
# Training step  30
# ...

# %%
print(accuracy/len(testloader))
# Out:
# 0.9333333373069763

# %%
torch.save(model, 'aerialmodel.pth')

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model=torch.load('aerialmodel.pth')

# %%
def predict_image(image):
    image_tensor = test_transforms(image).float()
    image_tensor = image_tensor.unsqueeze_(0)
    input = Variable(image_tensor)
    input = input.to(device)
    output = model(input)
    index = output.data.cpu().numpy().argmax()
    return index

# %%
to_pil = transforms.ToPILImage()
images, labels = get_random_images(5)
font1 = {'family': 'DejaVu Sans', 'color': 'white'}
fig=plt.figure(figsize=(20,10))

classes=trainloader.dataset.classes
for ii in range(len(images)):
    image = to_pil(images[ii])
    index = predict_image(image)
    sub = fig.add_subplot(1, len(images), ii+1)
    res = int(labels[ii]) == index
    plt.rcParams['text.color'] = 'w'
    sub.set_title(str(classes[index]) + ":" + str(res))
    plt.axis('off')
    plt.imshow(image)
plt.show()
